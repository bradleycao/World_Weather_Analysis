# %%
import pandas as pd
import numpy as np

# %%
# Create a set of random latitude and longtitude combinations.
lats = np.random.uniform(-90.000, 90.000, size = 2000)
lngs = np.random.uniform(-180.000, 180.000, size = 2000)
lat_lng = zip(lats,lngs)

# %%
# Add the lats and longs to a list
coordinates = list(lat_lng)

# %%
# Import citiPy
from citipy import citipy

# %%
# Create a list for holding the cities
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Create counters.
record_count = 1
set_count = 1

# %%
# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                         "Country": city_country,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Current Description": city_description})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping ...")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | rawson
# Processing Record 3 of Set 1 | yuksekova
# Processing Record 4 of Set 1 | misratah
# Processing Record 5 of Set 1 | teguise
# Processing Record 6 of Set 1 | tuktoyaktuk
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | thompson
# Processing Record 9 of Set 1 | qaanaaq
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | paamiut
# Processing Record 12 of Set 1 | sitka
# Processing Record 13 of Set 1 | goedereede
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | kidal
# Processing Record 16 of Set 1 | hamilton
# Processing Record 17 of Set 1 | saint austell
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | paramonga
# Processing Record 21 of Set 1 | grindavik
# Processing Record 22 of Set 1 | upernavik
# Processing Record 23 of Set 1 | nantucket
# Processing Record 24 of Set 1 | barrow
# Processing Record 25 of Set 1 | makokou
# Processing Record 26 of Set 1 | raudeberg
# Processing Record 27 of Set 1 | nikolskoye
# Processing Record 28 of Set 1 | faanui
# Processing Record 29 of Set 1 | tiksi
# Processing Record 30 of Set 1 | fairbanks
# Processing Record 31 of Set 1 | muros
# Processing Record 32 of Set 1 | clyde river
# Processing Record 33 of Set 1 | san quintin
# Processing Record 34 of Set 1 | attawapiskat
# City not found. Skipping ...
# Processing Record 35 of Set 1 | kulhudhuffushi
# Processing Record 36 of Set 1 | viedma
# Processing Record 37 of Set 1 | salalah
# Processing Record 38 of Set 1 | rocha
# Processing Record 39 of Set 1 | tasiilaq
# Processing Record 40 of Set 1 | broome
# Processing Record 41 of Set 1 | coquimbo
# Processing Record 42 of Set 1 | sentyabrskiy
# City not found. Skipping ...
# Processing Record 43 of Set 1 | cam pha
# City not found. Skipping ...
# Processing Record 44 of Set 1 | belushya guba
# City not found. Skipping ...
# Processing Record 45 of Set 1 | kingman
# Processing Record 46 of Set 1 | esperance
# Processing Record 47 of Set 1 | college
# Processing Record 48 of Set 1 | brae
# Processing Record 49 of Set 1 | saint-philippe
# Processing Record 50 of Set 1 | bumba
# Processing Record 1 of Set 2 | east london
# Processing Record 2 of Set 2 | kara-tyube
# Processing Record 3 of Set 2 | ixtapa
# Processing Record 4 of Set 2 | turayf
# Processing Record 5 of Set 2 | bredasdorp
# Processing Record 6 of Set 2 | fortuna
# Processing Record 7 of Set 2 | grand gaube
# Processing Record 8 of Set 2 | hobart
# Processing Record 9 of Set 2 | turukhansk
# Processing Record 10 of Set 2 | amahai
# Processing Record 11 of Set 2 | ribeira grande
# Processing Record 12 of Set 2 | marcona
# City not found. Skipping ...
# Processing Record 13 of Set 2 | sarangani
# Processing Record 14 of Set 2 | soto la marina
# Processing Record 15 of Set 2 | funadhoo
# Processing Record 16 of Set 2 | svetlogorsk
# Processing Record 17 of Set 2 | vardo
# Processing Record 18 of Set 2 | vaini
# Processing Record 19 of Set 2 | yumen
# Processing Record 20 of Set 2 | amderma
# City not found. Skipping ...
# Processing Record 21 of Set 2 | avarua
# Processing Record 22 of Set 2 | saskylakh
# Processing Record 23 of Set 2 | briancon
# Processing Record 24 of Set 2 | synya
# Processing Record 25 of Set 2 | dikson
# Processing Record 26 of Set 2 | longyearbyen
# Processing Record 27 of Set 2 | ushuaia
# Processing Record 28 of Set 2 | mataura
# Processing Record 29 of Set 2 | dunedin
# Processing Record 30 of Set 2 | atuona
# Processing Record 31 of Set 2 | kamina
# Processing Record 32 of Set 2 | wuda
# Processing Record 33 of Set 2 | kodinsk
# Processing Record 34 of Set 2 | torbay
# Processing Record 35 of Set 2 | vila velha
# Processing Record 36 of Set 2 | cap estate
# Processing Record 37 of Set 2 | chokurdakh
# Processing Record 38 of Set 2 | puerto ayora
# Processing Record 39 of Set 2 | jos
# Processing Record 40 of Set 2 | half moon bay
# Processing Record 41 of Set 2 | san andres
# Processing Record 42 of Set 2 | kaitangata
# Processing Record 43 of Set 2 | ubinskoye
# Processing Record 44 of Set 2 | punta arenas
# Processing Record 45 of Set 2 | new norfolk
# Processing Record 46 of Set 2 | albany
# Processing Record 47 of Set 2 | kavaratti
# Processing Record 48 of Set 2 | iqaluit
# Processing Record 49 of Set 2 | port elizabeth
# Processing Record 50 of Set 2 | banjar
# Processing Record 1 of Set 3 | daru
# Processing Record 2 of Set 3 | yellowknife
# Processing Record 3 of Set 3 | novo aripuana
# Processing Record 4 of Set 3 | kahului
# Processing Record 5 of Set 3 | khatanga
# Processing Record 6 of Set 3 | hovd
# Processing Record 7 of Set 3 | kavieng
# Processing Record 8 of Set 3 | sabha
# Processing Record 9 of Set 3 | matagami
# Processing Record 10 of Set 3 | provideniya
# Processing Record 11 of Set 3 | aracuai
# Processing Record 12 of Set 3 | lypnyazhka
# Processing Record 13 of Set 3 | formoso do araguaia
# City not found. Skipping ...
# Processing Record 14 of Set 3 | juan lacaze
# Processing Record 15 of Set 3 | maniitsoq
# Processing Record 16 of Set 3 | cape town
# Processing Record 17 of Set 3 | longkou
# Processing Record 18 of Set 3 | cap malheureux
# Processing Record 19 of Set 3 | vila franca do campo
# Processing Record 20 of Set 3 | carnarvon
# Processing Record 21 of Set 3 | kodiak
# Processing Record 22 of Set 3 | sola
# Processing Record 23 of Set 3 | nizhneyansk
# City not found. Skipping ...
# Processing Record 24 of Set 3 | riaba
# City not found. Skipping ...
# Processing Record 25 of Set 3 | isla mujeres
# Processing Record 26 of Set 3 | butaritari
# Processing Record 27 of Set 3 | vestmannaeyjar
# Processing Record 28 of Set 3 | nadym
# Processing Record 29 of Set 3 | ballina
# Processing Record 30 of Set 3 | saint george
# Processing Record 31 of Set 3 | taolanaro
# City not found. Skipping ...
# Processing Record 32 of Set 3 | yining
# Processing Record 33 of Set 3 | chuy
# Processing Record 34 of Set 3 | severo-kurilsk
# Processing Record 35 of Set 3 | arraial do cabo
# Processing Record 36 of Set 3 | mys shmidta
# City not found. Skipping ...
# Processing Record 37 of Set 3 | comodoro rivadavia
# Processing Record 38 of Set 3 | marawi
# Processing Record 39 of Set 3 | valparaiso
# Processing Record 40 of Set 3 | georgetown
# Processing Record 41 of Set 3 | phan thiet
# Processing Record 42 of Set 3 | sokoto
# Processing Record 43 of Set 3 | narsaq
# Processing Record 44 of Set 3 | eyl
# Processing Record 45 of Set 3 | nanortalik
# Processing Record 46 of Set 3 | lata
# Processing Record 47 of Set 3 | gladstone
# Processing Record 48 of Set 3 | aleppo
# Processing Record 49 of Set 3 | emiliano zapata
# Processing Record 50 of Set 3 | tortoli
# Processing Record 1 of Set 4 | roma
# Processing Record 2 of Set 4 | tsihombe
# City not found. Skipping ...
# Processing Record 3 of Set 4 | port alfred
# Processing Record 4 of Set 4 | aklavik
# Processing Record 5 of Set 4 | borger
# Processing Record 6 of Set 4 | cayenne
# Processing Record 7 of Set 4 | astana
# Processing Record 8 of Set 4 | hithadhoo
# Processing Record 9 of Set 4 | xining
# Processing Record 10 of Set 4 | tarudant
# City not found. Skipping ...
# Processing Record 11 of Set 4 | kapaa
# Processing Record 12 of Set 4 | jingdezhen
# Processing Record 13 of Set 4 | havelock
# Processing Record 14 of Set 4 | lasa
# Processing Record 15 of Set 4 | pangnirtung
# Processing Record 16 of Set 4 | codrington
# Processing Record 17 of Set 4 | kamen-na-obi
# Processing Record 18 of Set 4 | vaitupu
# City not found. Skipping ...
# Processing Record 19 of Set 4 | altenstadt
# Processing Record 20 of Set 4 | victoria
# Processing Record 21 of Set 4 | ust-nera
# Processing Record 22 of Set 4 | coihaique
# Processing Record 23 of Set 4 | bianzhuang
# Processing Record 24 of Set 4 | airai
# Processing Record 25 of Set 4 | isangel
# Processing Record 26 of Set 4 | manono
# Processing Record 27 of Set 4 | barranca de upia
# Processing Record 28 of Set 4 | santa rosa
# Processing Record 29 of Set 4 | ostrovnoy
# Processing Record 30 of Set 4 | bluff
# Processing Record 31 of Set 4 | andilamena
# Processing Record 32 of Set 4 | dali
# Processing Record 33 of Set 4 | zhuanghe
# Processing Record 34 of Set 4 | sao filipe
# Processing Record 35 of Set 4 | lagoa
# Processing Record 36 of Set 4 | cidreira
# Processing Record 37 of Set 4 | nagato
# Processing Record 38 of Set 4 | san patricio
# Processing Record 39 of Set 4 | ardrishaig
# Processing Record 40 of Set 4 | kupang
# Processing Record 41 of Set 4 | haines junction
# Processing Record 42 of Set 4 | biltine
# Processing Record 43 of Set 4 | miraflores
# Processing Record 44 of Set 4 | nortelandia
# Processing Record 45 of Set 4 | asau
# Processing Record 46 of Set 4 | mar del plata
# Processing Record 47 of Set 4 | dicabisagan
# Processing Record 48 of Set 4 | luena
# Processing Record 49 of Set 4 | gejiu
# Processing Record 50 of Set 4 | cherskiy
# Processing Record 1 of Set 5 | himora
# City not found. Skipping ...
# Processing Record 2 of Set 5 | aljezur
# Processing Record 3 of Set 5 | arroyo
# Processing Record 4 of Set 5 | hami
# Processing Record 5 of Set 5 | sistranda
# Processing Record 6 of Set 5 | bolungarvik
# City not found. Skipping ...
# Processing Record 7 of Set 5 | khonuu
# City not found. Skipping ...
# Processing Record 8 of Set 5 | ningxiang
# Processing Record 9 of Set 5 | saint-francois
# Processing Record 10 of Set 5 | arnsberg
# Processing Record 11 of Set 5 | qasigiannguit
# Processing Record 12 of Set 5 | la primavera
# Processing Record 13 of Set 5 | dingle
# Processing Record 14 of Set 5 | vrangel
# Processing Record 15 of Set 5 | inhambane
# Processing Record 16 of Set 5 | ziro
# Processing Record 17 of Set 5 | sao joao de pirabas
# Processing Record 18 of Set 5 | trelew
# Processing Record 19 of Set 5 | adre
# Processing Record 20 of Set 5 | vanimo
# Processing Record 21 of Set 5 | asia
# Processing Record 22 of Set 5 | mahebourg
# Processing Record 23 of Set 5 | straja
# Processing Record 24 of Set 5 | nago
# Processing Record 25 of Set 5 | panguipulli
# Processing Record 26 of Set 5 | markova
# Processing Record 27 of Set 5 | hohhot
# Processing Record 28 of Set 5 | tupik
# Processing Record 29 of Set 5 | rio gallegos
# Processing Record 30 of Set 5 | geraldton
# Processing Record 31 of Set 5 | chancay
# Processing Record 32 of Set 5 | rodrigues alves
# Processing Record 33 of Set 5 | visnes
# Processing Record 34 of Set 5 | mezhdurechenskiy
# Processing Record 35 of Set 5 | komsomolskiy
# Processing Record 36 of Set 5 | visby
# Processing Record 37 of Set 5 | trat
# Processing Record 38 of Set 5 | yayva
# Processing Record 39 of Set 5 | menongue
# Processing Record 40 of Set 5 | maunabo
# Processing Record 41 of Set 5 | ahipara
# Processing Record 42 of Set 5 | mount gambier
# Processing Record 43 of Set 5 | surt
# Processing Record 44 of Set 5 | mogadishu
# Processing Record 45 of Set 5 | voh
# Processing Record 46 of Set 5 | cedar falls
# Processing Record 47 of Set 5 | pedasi
# Processing Record 48 of Set 5 | fare
# Processing Record 49 of Set 5 | russell
# Processing Record 50 of Set 5 | meulaboh
# Processing Record 1 of Set 6 | eureka
# Processing Record 2 of Set 6 | pisco
# Processing Record 3 of Set 6 | kaabong
# Processing Record 4 of Set 6 | catia la mar
# Processing Record 5 of Set 6 | san joaquin
# Processing Record 6 of Set 6 | bambous virieux
# Processing Record 7 of Set 6 | zyryanka
# Processing Record 8 of Set 6 | ayan
# Processing Record 9 of Set 6 | boone
# Processing Record 10 of Set 6 | mananara
# Processing Record 11 of Set 6 | brora
# Processing Record 12 of Set 6 | guerrero negro
# Processing Record 13 of Set 6 | buqayq
# City not found. Skipping ...
# Processing Record 14 of Set 6 | bulaevo
# Processing Record 15 of Set 6 | kruisfontein
# Processing Record 16 of Set 6 | annau
# Processing Record 17 of Set 6 | gueret
# Processing Record 18 of Set 6 | mao
# Processing Record 19 of Set 6 | kununurra
# Processing Record 20 of Set 6 | temaraia
# City not found. Skipping ...
# Processing Record 21 of Set 6 | bilibino
# Processing Record 22 of Set 6 | cabedelo
# Processing Record 23 of Set 6 | kargasok
# Processing Record 24 of Set 6 | narrabri
# Processing Record 25 of Set 6 | karakol
# Processing Record 26 of Set 6 | ilulissat
# Processing Record 27 of Set 6 | halalo
# City not found. Skipping ...
# Processing Record 28 of Set 6 | andenes
# Processing Record 29 of Set 6 | vryheid
# Processing Record 30 of Set 6 | touros
# Processing Record 31 of Set 6 | vavuniya
# Processing Record 32 of Set 6 | quimper
# Processing Record 33 of Set 6 | illoqqortoormiut
# City not found. Skipping ...
# Processing Record 34 of Set 6 | the valley
# Processing Record 35 of Set 6 | lulea
# Processing Record 36 of Set 6 | tautira
# Processing Record 37 of Set 6 | kysyl-syr
# Processing Record 38 of Set 6 | bengkulu
# Processing Record 39 of Set 6 | louisbourg
# City not found. Skipping ...
# Processing Record 40 of Set 6 | nome
# Processing Record 41 of Set 6 | grand river south east
# City not found. Skipping ...
# Processing Record 42 of Set 6 | kracheh
# City not found. Skipping ...
# Processing Record 43 of Set 6 | badaojiang
# City not found. Skipping ...
# Processing Record 44 of Set 6 | macultepec
# Processing Record 45 of Set 6 | gorontalo
# Processing Record 46 of Set 6 | guadalajara
# Processing Record 47 of Set 6 | jackson
# Processing Record 48 of Set 6 | sao joao da barra
# Processing Record 49 of Set 6 | mathathane
# Processing Record 50 of Set 6 | namatanai
# Processing Record 1 of Set 7 | plettenberg bay
# Processing Record 2 of Set 7 | praia da vitoria
# Processing Record 3 of Set 7 | yuzhno-yeniseyskiy
# City not found. Skipping ...
# Processing Record 4 of Set 7 | yulara
# Processing Record 5 of Set 7 | lorengau
# Processing Record 6 of Set 7 | scottsburgh
# City not found. Skipping ...
# Processing Record 7 of Set 7 | trairi
# Processing Record 8 of Set 7 | nabire
# Processing Record 9 of Set 7 | bogoroditsk
# Processing Record 10 of Set 7 | vila
# Processing Record 11 of Set 7 | salou
# Processing Record 12 of Set 7 | tessalit
# Processing Record 13 of Set 7 | richards bay
# Processing Record 14 of Set 7 | chagda
# City not found. Skipping ...
# Processing Record 15 of Set 7 | kokkola
# Processing Record 16 of Set 7 | barentsburg
# City not found. Skipping ...
# Processing Record 17 of Set 7 | les cayes
# Processing Record 18 of Set 7 | anadyr
# Processing Record 19 of Set 7 | port-cartier
# Processing Record 20 of Set 7 | palm coast
# Processing Record 21 of Set 7 | kuche
# City not found. Skipping ...
# Processing Record 22 of Set 7 | sault sainte marie
# Processing Record 23 of Set 7 | kentau
# Processing Record 24 of Set 7 | tekeli
# Processing Record 25 of Set 7 | port hardy
# Processing Record 26 of Set 7 | dom pedrito
# Processing Record 27 of Set 7 | taoudenni
# Processing Record 28 of Set 7 | sept-iles
# Processing Record 29 of Set 7 | brazzaville
# Processing Record 30 of Set 7 | newcastle
# Processing Record 31 of Set 7 | sofia
# Processing Record 32 of Set 7 | talcahuano
# Processing Record 33 of Set 7 | ilebo
# Processing Record 34 of Set 7 | chernyshevskiy
# Processing Record 35 of Set 7 | aqtobe
# Processing Record 36 of Set 7 | coxim
# Processing Record 37 of Set 7 | myitkyina
# Processing Record 38 of Set 7 | beringovskiy
# Processing Record 39 of Set 7 | barcelos
# Processing Record 40 of Set 7 | sleaford
# Processing Record 41 of Set 7 | jaque
# Processing Record 42 of Set 7 | chunoyar
# Processing Record 43 of Set 7 | rudnogorsk
# Processing Record 44 of Set 7 | rosetta
# Processing Record 45 of Set 7 | tambau
# Processing Record 46 of Set 7 | presidencia roque saenz pena
# Processing Record 47 of Set 7 | buariki
# City not found. Skipping ...
# Processing Record 48 of Set 7 | ponta do sol
# Processing Record 49 of Set 7 | castro
# Processing Record 50 of Set 7 | nanchong
# Processing Record 1 of Set 8 | bubaque
# Processing Record 2 of Set 8 | porto walter
# Processing Record 3 of Set 8 | pochutla
# Processing Record 4 of Set 8 | ancud
# Processing Record 5 of Set 8 | qianan
# Processing Record 6 of Set 8 | kosikha
# Processing Record 7 of Set 8 | tazovskiy
# Processing Record 8 of Set 8 | aflu
# City not found. Skipping ...
# Processing Record 9 of Set 8 | beyneu
# Processing Record 10 of Set 8 | road town
# Processing Record 11 of Set 8 | sur
# Processing Record 12 of Set 8 | sao miguel do araguaia
# Processing Record 13 of Set 8 | sabang
# Processing Record 14 of Set 8 | marsa matruh
# Processing Record 15 of Set 8 | nova venecia
# Processing Record 16 of Set 8 | noyabrsk
# Processing Record 17 of Set 8 | hobyo
# Processing Record 18 of Set 8 | los llanos de aridane
# Processing Record 19 of Set 8 | bondo
# Processing Record 20 of Set 8 | port-gentil
# Processing Record 21 of Set 8 | ajdabiya
# Processing Record 22 of Set 8 | ucluelet
# Processing Record 23 of Set 8 | talara
# Processing Record 24 of Set 8 | kirensk
# Processing Record 25 of Set 8 | margate
# Processing Record 26 of Set 8 | cockburn town
# Processing Record 27 of Set 8 | bentiu
# Processing Record 28 of Set 8 | jiddah
# City not found. Skipping ...
# Processing Record 29 of Set 8 | vaitape
# Processing Record 30 of Set 8 | jaguarari
# Processing Record 31 of Set 8 | luderitz
# Processing Record 32 of Set 8 | ciudad bolivar
# Processing Record 33 of Set 8 | aguimes
# Processing Record 34 of Set 8 | flinders
# Processing Record 35 of Set 8 | porto novo
# Processing Record 36 of Set 8 | ati
# Processing Record 37 of Set 8 | yar-sale
# Processing Record 38 of Set 8 | srednekolymsk
# Processing Record 39 of Set 8 | putina
# Processing Record 40 of Set 8 | porto velho
# Processing Record 41 of Set 8 | tucuma
# Processing Record 42 of Set 8 | nguiu
# City not found. Skipping ...
# Processing Record 43 of Set 8 | mehamn
# Processing Record 44 of Set 8 | ascension
# Processing Record 45 of Set 8 | meyungs
# City not found. Skipping ...
# Processing Record 46 of Set 8 | abu dhabi
# Processing Record 47 of Set 8 | saleaula
# City not found. Skipping ...
# Processing Record 48 of Set 8 | kurtalan
# Processing Record 49 of Set 8 | carutapera
# Processing Record 50 of Set 8 | tawang
# Processing Record 1 of Set 9 | umzimvubu
# City not found. Skipping ...
# Processing Record 2 of Set 9 | bandar-e lengeh
# Processing Record 3 of Set 9 | port lincoln
# Processing Record 4 of Set 9 | vao
# Processing Record 5 of Set 9 | el tocuyo
# Processing Record 6 of Set 9 | avera
# Processing Record 7 of Set 9 | aswan
# Processing Record 8 of Set 9 | praia
# Processing Record 9 of Set 9 | muriti
# Processing Record 10 of Set 9 | gazojak
# Processing Record 11 of Set 9 | makakilo city
# Processing Record 12 of Set 9 | mandalgovi
# Processing Record 13 of Set 9 | zamosc
# Processing Record 14 of Set 9 | padang
# Processing Record 15 of Set 9 | pevek
# Processing Record 16 of Set 9 | strezhevoy
# Processing Record 17 of Set 9 | yerbogachen
# Processing Record 18 of Set 9 | ahuimanu
# Processing Record 19 of Set 9 | benjamin aceval
# Processing Record 20 of Set 9 | bafoulabe
# Processing Record 21 of Set 9 | saldanha
# Processing Record 22 of Set 9 | afua
# Processing Record 23 of Set 9 | recco
# Processing Record 24 of Set 9 | cuamba
# Processing Record 25 of Set 9 | satka
# Processing Record 26 of Set 9 | gogrial
# Processing Record 27 of Set 9 | warwick
# Processing Record 28 of Set 9 | baghdad
# Processing Record 29 of Set 9 | karratha
# Processing Record 30 of Set 9 | chipiona
# Processing Record 31 of Set 9 | burica
# City not found. Skipping ...
# Processing Record 32 of Set 9 | hasaki
# Processing Record 33 of Set 9 | constitucion
# Processing Record 34 of Set 9 | talnakh
# Processing Record 35 of Set 9 | kropotkin
# Processing Record 36 of Set 9 | dukat
# Processing Record 37 of Set 9 | king city
# Processing Record 38 of Set 9 | paciran
# Processing Record 39 of Set 9 | novoorsk
# Processing Record 40 of Set 9 | galesong
# Processing Record 41 of Set 9 | hualmay
# Processing Record 42 of Set 9 | balkanabat
# Processing Record 43 of Set 9 | gornopravdinsk
# Processing Record 44 of Set 9 | khandyga
# Processing Record 45 of Set 9 | gazni
# City not found. Skipping ...
# Processing Record 46 of Set 9 | staryy merchyk
# Processing Record 47 of Set 9 | cabo san lucas
# Processing Record 48 of Set 9 | korla
# Processing Record 49 of Set 9 | glencoe
# Processing Record 50 of Set 9 | robertsport
# Processing Record 1 of Set 10 | sfantu gheorghe
# Processing Record 2 of Set 10 | mujiayingzi
# Processing Record 3 of Set 10 | bitung
# Processing Record 4 of Set 10 | suntar
# Processing Record 5 of Set 10 | hervey bay
# Processing Record 6 of Set 10 | winslow
# Processing Record 7 of Set 10 | barra patuca
# Processing Record 8 of Set 10 | ca mau
# Processing Record 9 of Set 10 | quelimane
# Processing Record 10 of Set 10 | leningradskiy
# Processing Record 11 of Set 10 | sisimiut
# Processing Record 12 of Set 10 | ankola
# Processing Record 13 of Set 10 | issenye
# Processing Record 14 of Set 10 | letlhakane
# Processing Record 15 of Set 10 | mangai
# Processing Record 16 of Set 10 | talakan
# Processing Record 17 of Set 10 | gravdal
# Processing Record 18 of Set 10 | mamallapuram
# Processing Record 19 of Set 10 | kaffrine
# Processing Record 20 of Set 10 | saint-joseph
# Processing Record 21 of Set 10 | naze
# Processing Record 22 of Set 10 | togitsu
# Processing Record 23 of Set 10 | paradwip
# City not found. Skipping ...
# Processing Record 24 of Set 10 | quang ngai
# Processing Record 25 of Set 10 | shimoda
# Processing Record 26 of Set 10 | aykhal
# Processing Record 27 of Set 10 | salina
# Processing Record 28 of Set 10 | tambura
# Processing Record 29 of Set 10 | bathsheba
# Processing Record 30 of Set 10 | cochrane
# Processing Record 31 of Set 10 | wahran
# City not found. Skipping ...
# Processing Record 32 of Set 10 | lashio
# Processing Record 33 of Set 10 | lerwick
# Processing Record 34 of Set 10 | santa cruz
# Processing Record 35 of Set 10 | puerto quijarro
# Processing Record 36 of Set 10 | punta alta
# Processing Record 37 of Set 10 | glossa
# Processing Record 38 of Set 10 | boulsa
# Processing Record 39 of Set 10 | ossora
# Processing Record 40 of Set 10 | byron bay
# Processing Record 41 of Set 10 | taltal
# Processing Record 42 of Set 10 | bargal
# City not found. Skipping ...
# Processing Record 43 of Set 10 | pinega
# Processing Record 44 of Set 10 | rudnyy
# Processing Record 45 of Set 10 | nyurba
# Processing Record 46 of Set 10 | tanete
# Processing Record 47 of Set 10 | kyabe
# Processing Record 48 of Set 10 | natal
# Processing Record 49 of Set 10 | puerto asis
# Processing Record 50 of Set 10 | vostok
# Processing Record 1 of Set 11 | lodja
# Processing Record 2 of Set 11 | kaeo
# Processing Record 3 of Set 11 | wollongong
# Processing Record 4 of Set 11 | manzhouli
# Processing Record 5 of Set 11 | olafsvik
# Processing Record 6 of Set 11 | melnikovo
# Processing Record 7 of Set 11 | dabat
# Processing Record 8 of Set 11 | zhaotong
# Processing Record 9 of Set 11 | sao miguel do oeste
# City not found. Skipping ...
# Processing Record 10 of Set 11 | paralimni
# Processing Record 11 of Set 11 | piran
# Processing Record 12 of Set 11 | churapcha
# Processing Record 13 of Set 11 | alihe
# Processing Record 14 of Set 11 | kokopo
# Processing Record 15 of Set 11 | qena
# Processing Record 16 of Set 11 | sambava
# Processing Record 17 of Set 11 | bambanglipuro
# Processing Record 18 of Set 11 | karaton
# Processing Record 19 of Set 11 | porto belo
# Processing Record 20 of Set 11 | aksha
# Processing Record 21 of Set 11 | pierreville
# Processing Record 22 of Set 11 | ola
# Processing Record 23 of Set 11 | villazon
# Processing Record 24 of Set 11 | saint anthony
# Processing Record 25 of Set 11 | sao felix do xingu
# Processing Record 26 of Set 11 | saurimo
# Processing Record 27 of Set 11 | sainte-marie
# Processing Record 28 of Set 11 | gwadar
# Processing Record 29 of Set 11 | marshfield
# Processing Record 30 of Set 11 | krasnorechenskiy
# Processing Record 31 of Set 11 | husavik
# Processing Record 32 of Set 11 | wukari
# Processing Record 33 of Set 11 | kadoma
# Processing Record 34 of Set 11 | macapa
# Processing Record 35 of Set 11 | maloshuyka
# City not found. Skipping ...
# Processing Record 36 of Set 11 | lebu
# Processing Record 37 of Set 11 | itoigawa
# Processing Record 38 of Set 11 | minas
# Processing Record 39 of Set 11 | nelson
# Processing Record 40 of Set 11 | tumannyy
# City not found. Skipping ...
# Processing Record 41 of Set 11 | charters towers
# Processing Record 42 of Set 11 | aranda de duero
# Processing Record 43 of Set 11 | sorvag
# City not found. Skipping ...
# Processing Record 44 of Set 11 | kegayli
# City not found. Skipping ...
# Processing Record 45 of Set 11 | katsuura
# Processing Record 46 of Set 11 | dwarka
# Processing Record 47 of Set 11 | shama
# Processing Record 48 of Set 11 | leh
# Processing Record 49 of Set 11 | neftcala
# Processing Record 50 of Set 11 | lompoc
# Processing Record 1 of Set 12 | taber
# Processing Record 2 of Set 12 | moron
# Processing Record 3 of Set 12 | manokwari
# Processing Record 4 of Set 12 | tayu
# Processing Record 5 of Set 12 | inhuma
# Processing Record 6 of Set 12 | skvyra
# Processing Record 7 of Set 12 | shubarshi
# Processing Record 8 of Set 12 | daye
# Processing Record 9 of Set 12 | macheng
# Processing Record 10 of Set 12 | flin flon
# Processing Record 11 of Set 12 | hadrut
# Processing Record 12 of Set 12 | selikhino
# Processing Record 13 of Set 12 | sompeta
# Processing Record 14 of Set 12 | awjilah
# Processing Record 15 of Set 12 | bhadrachalam
# Processing Record 16 of Set 12 | bhaderwah
# Processing Record 17 of Set 12 | sterling
# Processing Record 18 of Set 12 | necochea
# Processing Record 19 of Set 12 | solnechnyy
# Processing Record 20 of Set 12 | coahuayana
# Processing Record 21 of Set 12 | bandarbeyla
# Processing Record 22 of Set 12 | puerto del rosario
# Processing Record 23 of Set 12 | saku
# Processing Record 24 of Set 12 | sao joao evangelista
# Processing Record 25 of Set 12 | paucartambo
# City not found. Skipping ...
# Processing Record 26 of Set 12 | toowoomba
# Processing Record 27 of Set 12 | puerto baquerizo moreno
# Processing Record 28 of Set 12 | buala
# Processing Record 29 of Set 12 | burhaniye
# Processing Record 30 of Set 12 | outjo
# Processing Record 31 of Set 12 | aloleng
# Processing Record 32 of Set 12 | mali
# Processing Record 33 of Set 12 | celestun
# Processing Record 34 of Set 12 | viligili
# City not found. Skipping ...
# Processing Record 35 of Set 12 | galena park
# Processing Record 36 of Set 12 | mergui
# City not found. Skipping ...
# Processing Record 37 of Set 12 | stokmarknes
# Processing Record 38 of Set 12 | borama
# City not found. Skipping ...
# Processing Record 39 of Set 12 | sangar
# Processing Record 40 of Set 12 | broken hill
# Processing Record 41 of Set 12 | salmas
# Processing Record 42 of Set 12 | pitimbu
# Processing Record 43 of Set 12 | olinda
# Processing Record 44 of Set 12 | camacha
# Processing Record 45 of Set 12 | te anau
# Processing Record 46 of Set 12 | norman wells
# Processing Record 47 of Set 12 | pertuis
# Processing Record 48 of Set 12 | trincomalee
# Processing Record 49 of Set 12 | kailua
# Processing Record 50 of Set 12 | bardiyah
# Processing Record 1 of Set 13 | lavrentiya
# Processing Record 2 of Set 13 | oriximina
# Processing Record 3 of Set 13 | japura
# Processing Record 4 of Set 13 | staryy nadym
# Processing Record 5 of Set 13 | palabuhanratu
# City not found. Skipping ...
# Processing Record 6 of Set 13 | fort nelson
# Processing Record 7 of Set 13 | lima
# Processing Record 8 of Set 13 | manaquiri
# Processing Record 9 of Set 13 | formosa
# Processing Record 10 of Set 13 | westport
# Processing Record 11 of Set 13 | khudumelapye
# Processing Record 12 of Set 13 | thunder bay
# Processing Record 13 of Set 13 | mongo
# Processing Record 14 of Set 13 | candating
# Processing Record 15 of Set 13 | malwan
# City not found. Skipping ...
# Processing Record 16 of Set 13 | clermont
# Processing Record 17 of Set 13 | nishihara
# Processing Record 18 of Set 13 | iwanai
# Processing Record 19 of Set 13 | zholymbet
# Processing Record 20 of Set 13 | buraydah
# Processing Record 21 of Set 13 | santa vitoria do palmar
# Processing Record 22 of Set 13 | buncrana
# Processing Record 23 of Set 13 | sidhi
# Processing Record 24 of Set 13 | udachnyy
# Processing Record 25 of Set 13 | zhezkazgan
# Processing Record 26 of Set 13 | sorgun
# Processing Record 27 of Set 13 | weyburn
# Processing Record 28 of Set 13 | porbandar
# Processing Record 29 of Set 13 | amnat charoen
# Processing Record 30 of Set 13 | bat khela
# Processing Record 31 of Set 13 | evensk
# Processing Record 32 of Set 13 | marzuq
# Processing Record 33 of Set 13 | ushirombo
# Processing Record 34 of Set 13 | sinjah
# City not found. Skipping ...
# Processing Record 35 of Set 13 | kudahuvadhoo
# Processing Record 36 of Set 13 | arman
# Processing Record 37 of Set 13 | ponta delgada
# Processing Record 38 of Set 13 | fethiye
# Processing Record 39 of Set 13 | port victoria
# Processing Record 40 of Set 13 | lac du bonnet
# Processing Record 41 of Set 13 | moroni
# Processing Record 42 of Set 13 | beroroha
# Processing Record 43 of Set 13 | portland
# Processing Record 44 of Set 13 | klaksvik
# Processing Record 45 of Set 13 | litoral del san juan
# City not found. Skipping ...
# Processing Record 46 of Set 13 | mpika
# Processing Record 47 of Set 13 | mizdah
# Processing Record 48 of Set 13 | mount isa
# Processing Record 49 of Set 13 | tawkar
# City not found. Skipping ...
# Processing Record 50 of Set 13 | sharlyk
# Processing Record 1 of Set 14 | sorrento
# Processing Record 2 of Set 14 | sioux lookout
# Processing Record 3 of Set 14 | atherton
# Processing Record 4 of Set 14 | cugir
# Processing Record 5 of Set 14 | poum
# Processing Record 6 of Set 14 | hvolsvollur
# Processing Record 7 of Set 14 | worland
# Processing Record 8 of Set 14 | olga
# Processing Record 9 of Set 14 | changli
# Processing Record 10 of Set 14 | oyama
# Processing Record 11 of Set 14 | santa isabel
# Processing Record 12 of Set 14 | kirovskiy
# Processing Record 13 of Set 14 | bousso
# Processing Record 14 of Set 14 | iskateley
# Processing Record 15 of Set 14 | stornoway
# Processing Record 16 of Set 14 | zapolyarnyy
# Processing Record 17 of Set 14 | maxixe
# Processing Record 18 of Set 14 | chinsali
# Processing Record 19 of Set 14 | rapid city
# Processing Record 20 of Set 14 | hammerfest
# Processing Record 21 of Set 14 | hofn
# Processing Record 22 of Set 14 | sao jose da coroa grande
# Processing Record 23 of Set 14 | mishan
# Processing Record 24 of Set 14 | ishigaki
# Processing Record 25 of Set 14 | rungata
# City not found. Skipping ...
# Processing Record 26 of Set 14 | beloha
# Processing Record 27 of Set 14 | gurupa
# Processing Record 28 of Set 14 | parabel
# Processing Record 29 of Set 14 | amuntai
# Processing Record 30 of Set 14 | carira
# Processing Record 31 of Set 14 | chickasha
# Processing Record 32 of Set 14 | mandan
# Processing Record 33 of Set 14 | walvis bay
# Processing Record 34 of Set 14 | umm kaddadah
# Processing Record 35 of Set 14 | borogontsy
# Processing Record 36 of Set 14 | sakakah
# Processing Record 37 of Set 14 | kasempa
# Processing Record 38 of Set 14 | souillac
# Processing Record 39 of Set 14 | puerto escondido
# Processing Record 40 of Set 14 | dourbali
# Processing Record 41 of Set 14 | jinxiang
# Processing Record 42 of Set 14 | champerico
# Processing Record 43 of Set 14 | baoying
# Processing Record 44 of Set 14 | ust-ishim
# Processing Record 45 of Set 14 | ouro preto do oeste
# Processing Record 46 of Set 14 | the pas
# Processing Record 47 of Set 14 | berlin
# Processing Record 48 of Set 14 | faya
# Processing Record 49 of Set 14 | richard toll
# City not found. Skipping ...
# Processing Record 50 of Set 14 | prescott
# Processing Record 1 of Set 15 | aguacatan
# Processing Record 2 of Set 15 | omsukchan
# Processing Record 3 of Set 15 | man
# Processing Record 4 of Set 15 | tezu
# Processing Record 5 of Set 15 | bud
# Processing Record 6 of Set 15 | nouadhibou
# Processing Record 7 of Set 15 | atar
# Processing Record 8 of Set 15 | verkhozim
# Processing Record 9 of Set 15 | la asuncion
# Processing Record 10 of Set 15 | sovetskiy
# Processing Record 11 of Set 15 | eyrarbakki
# Processing Record 12 of Set 15 | chardara
# Processing Record 13 of Set 15 | zhaodong
# Processing Record 14 of Set 15 | corinto
# Processing Record 15 of Set 15 | lida
# Processing Record 16 of Set 15 | luanda
# Processing Record 17 of Set 15 | camana
# Processing Record 18 of Set 15 | zlobin
# Processing Record 19 of Set 15 | urucara
# Processing Record 20 of Set 15 | ipixuna
# Processing Record 21 of Set 15 | manuk mangkaw
# Processing Record 22 of Set 15 | tlaxiaco
# City not found. Skipping ...
# Processing Record 23 of Set 15 | shetpe
# Processing Record 24 of Set 15 | autazes
# Processing Record 25 of Set 15 | hoquiam
# Processing Record 26 of Set 15 | pangai
# Processing Record 27 of Set 15 | vydrino
# Processing Record 28 of Set 15 | bay roberts
# Processing Record 29 of Set 15 | mangalia
# Processing Record 30 of Set 15 | namibe
# Processing Record 31 of Set 15 | verin
# Processing Record 32 of Set 15 | lakeway
# Processing Record 33 of Set 15 | bourail
# Processing Record 34 of Set 15 | venice
# Processing Record 35 of Set 15 | amasia
# Processing Record 36 of Set 15 | jardim
# Processing Record 37 of Set 15 | amasya
# Processing Record 38 of Set 15 | qui nhon
# Processing Record 39 of Set 15 | arrifes
# Processing Record 40 of Set 15 | lokomotivnyy
# Processing Record 41 of Set 15 | tuy hoa
# Processing Record 42 of Set 15 | mayo
# Processing Record 43 of Set 15 | kieta
# Processing Record 44 of Set 15 | takoradi
# Processing Record 45 of Set 15 | huilong
# Processing Record 46 of Set 15 | nemuro
# Processing Record 47 of Set 15 | san ramon
# Processing Record 48 of Set 15 | lumby
# Processing Record 49 of Set 15 | contamana
# Processing Record 50 of Set 15 | rolla
# Processing Record 1 of Set 16 | deputatskiy
# Processing Record 2 of Set 16 | maceio
# Processing Record 3 of Set 16 | kloulklubed
# Processing Record 4 of Set 16 | cortez
# Processing Record 5 of Set 16 | nikolsk
# Processing Record 6 of Set 16 | bacolod
# Processing Record 7 of Set 16 | verkhnyaya inta
# Processing Record 8 of Set 16 | ariquemes
# Processing Record 9 of Set 16 | arenapolis
# Processing Record 10 of Set 16 | ouro fino
# Processing Record 11 of Set 16 | xiongshi
# City not found. Skipping ...
# Processing Record 12 of Set 16 | dubbo
# Processing Record 13 of Set 16 | birakan
# Processing Record 14 of Set 16 | sinnamary
# Processing Record 15 of Set 16 | inta
# Processing Record 16 of Set 16 | shizunai
# Processing Record 17 of Set 16 | brisbane
# Processing Record 18 of Set 16 | seybaplaya
# Processing Record 19 of Set 16 | bury saint edmunds
# City not found. Skipping ...
# Processing Record 20 of Set 16 | rio cuarto
# Processing Record 21 of Set 16 | taburi
# City not found. Skipping ...
# Processing Record 22 of Set 16 | ilinskiy
# Processing Record 23 of Set 16 | horqueta
# Processing Record 24 of Set 16 | malanje
# Processing Record 25 of Set 16 | karpathos
# Processing Record 26 of Set 16 | nicoya
# Processing Record 27 of Set 16 | chapais
# Processing Record 28 of Set 16 | bereda
# Processing Record 29 of Set 16 | carson city
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Busselton      AU -33.6500  115.3333     73.99        60           0
# 1       Rawson      AR -43.3002  -65.1023     60.85        57           0
# 2    Yuksekova      TR  37.5736   44.2872     15.01        93          96
# 3     Misratah      LY  32.3754   15.0925     63.91        55           0
# 4      Teguise      ES  29.0605  -13.5640     64.40        82          75
# 5  Tuktoyaktuk      CA  69.4541 -133.0374    -34.60        67          40
# 6         Hilo      US  19.7297 -155.0900     80.60        54          75
# 7     Thompson      CA  55.7435  -97.8558     14.00        92          90
# 8      Qaanaaq      GL  77.4840  -69.3632     -5.12        78          98
# 9      Rikitea      PF -23.1203 -134.9692     79.34        71          18
#
#    Wind Speed Current Description
# 0        1.01           clear sky
# 1       17.20           clear sky
# 2        4.50     overcast clouds
# 3       11.90           clear sky
# 4       14.97       broken clouds
# 5        3.44    scattered clouds
# 6        9.22       broken clouds
# 7        2.30          light snow
# 8        2.24     overcast clouds
# 9       11.72          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the city_data into a CSV.
city_data_df.to_csv(output_data_file, index_label = 'City_ID')
